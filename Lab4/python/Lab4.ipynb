# %% [markdown]
# # Digital Signal Processing
#
# ### MsCV - ViBOT - MAIA

# %% [markdown]
# The reasons to convert signals into frequency domain is to get the idea of different frequency components it is composed of. This might help to detect the required signals and classify them, for examples, speak or speech recognition from a sound wave, noise removal from the image, or finding recurring patterns within images.

# %%
# %matplotlib inline
# %pprint off

# To make some nice plot
import matplotlib.pyplot as plt
# To play with arrays
import numpy as np
from skimage import io
from skimage import img_as_float
from matplotlib import cm
from scipy.stats import norm
from scipy import signal
# Out:
# Pretty printing has been turned ON

# %% [markdown]
# # Discrete Fourier Transform
# The Discrete Fourier Transform (DFT) converts discrete data from a time domain into frequency domain. The DFT analyzes the finite segment in one period of an infinitely extended periodic signal, which is defined as:
# $$ X[n] = \sum^{N-1}_{k = 0} x[k] e^{-j(2\pi/N)kn}$$
#
#
# Note: The Fast Fourier Transform (FFT) is simply an algorithm to compute the DFT in a faster way!
#
# ## Exercise 1 -  ** DFT**
# **1.1** The DFT of a $5$ Hz sin wave sampled with the sampling of $f_s = 50$ Hz over 1000 (N = 1000) samples is computed as follows:

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# sin wave 
x_n = np.sin(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Sin wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.2** Compute the DFT of a cosine wave, how that differs from that of a sine wave ?

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# sin wave 
x_n = np.cos(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Cos wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.3** Use square wave using the same frequncy and sampling frequency.
#
# Note use `signal.square` to create your signal.

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# sin wave 
x_n = signal.square(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Square wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.4** Use white Gaussian noise N = 10000.
#
# (Note use `np.random.normal` to create your noise)

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.

mu = 0.
sigma = 1.
N = 10000

# Generate the data
x_n = np.random.normal(mu, sigma, (N, ))
# time vector for one second
#t = np.arange(0, 1., 1./fs)
t = np.arange(0, 1., 1./N)
# sin wave 
#x_n = signal.square(2*np.pi*f*t)
# Number of samples 
#N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1))
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('White Noise Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## Exercise 2 -  Sampling
#
# Generate and display the following signals of 1 sec duration.
# $$x[n] = 3 cos(2\pi\frac{f_{1}}{f_{s}}n) + 4 sin(2\pi\frac{f_{2}}{f_{s}}n)$$
# for $f_{1} = 5$ Hz and $f_{2} = 20$ Hz, sampled with the sampling frequencies of $f_{s} = [10, 20, 25, 40, 50, 100, 150]$

# %% [markdown]
# **2.1** Plot $x[n]$ for different sampling frequencies in time domain.

# %%
fs_arr =np.array([10., 20., 25., 40., 50., 100., 150.])
# Signal frequency and sampling frequency
f1 = 5.
f2 = 20.

# time vector for one second
for i in range(fs_arr.shape[0]):
    t = np.arange(0, 1., 1./fs_arr[i])
    # sin wave 
    x_n = 3*np.cos(2*np.pi*(f1)*t) + 4*np.sin(2*np.pi*(f2)*t)
    # Number of samples 
    plt.figure
    plt.subplot(211)
    plt.plot(t, x_n)
    plt.title('x[n]: fs = '+ str(fs_arr[i]))
    plt.xlabel('Time(sec)')
    plt.ylabel('Amplitude')
    plt.show()

# %% [markdown]
# **2.2.** Discuss the aliasing effects in the time domain:

# %% [markdown]
# **2.3** Compute the FFT of the above signals and display their centered frequency components.
# Discuss your observations.

# %%
N = 1000

for i in range(fs_arr.shape[0]):
    print (fs_arr[i])
    t = np.arange(0, 1., 1./fs_arr[i])
    # sin wave 
    x_n = 3*np.cos(2*np.pi*(f1)*t) + 4*np.sin(2*np.pi*(f2)*t)
    fr = (np.arange(-N/2,N/2,1)) * fs_arr[i]/N
    x_f = np.fft.fftshift(np.fft.fft(x_n, N))
    # Number of samples 
    plt.subplot(312)
    plt.plot(fr, x_f)
    plt.title('DFT: fs = '+ str(fs_arr[i]))
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('|X(f)|')
    plt.show()
    fr = (np.arange(-N/2,N/2,1)) * fs/N
# Out:
# 10.0
# C:\Users\USER\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 20.0
# 25.0
# 40.0
# 50.0
# 100.0
# 150.0

# %% [markdown]
# ## Exercise 3 - 1D  DFT for image classification
#
# 1D DFT can be applied to analyze the frequency components along the one dimensional profile of an image. Here we want to use these information to classify the images into two different classes (**barcode** and **non-barcode** classes)
# To do so we first
# * Load the images from 1D-DFT folder
#     * **3.1** you have to normalize and resize the images to the smallest size
#     * **3.2** Take 1D profile as shown in the example and compute its DFT.
# ![](profile1.png)
#
#     * **3.3** Separate the images to two different groups of **barcode** and **non-barcode** based on their frequency spectrum of their profile
# * Some information regarding the images:
#     * There are 54 images while Images [1, 2, 6, 44:54] are barcode images and the others are similar patterns.
#
# **3.4** Discuss your results

# %%
#Normalization function
def con_str(x):
    ### Find the maximum
    max_int = np.max(x)
    ### Find the minimum
    min_int = np.min(x)
    
    return np.round((x - min_int) * ((255. - 0.) / (max_int - min_int)) + 0.).astype('uint8')



Path = '../images/1D-DFT/'
import os, os.path
from skimage import color
from scipy import misc
from skimage import transform 


filenames = sorted([f for f in os.listdir(Path)])

#empty arrays each to store barcode and non-barcode images respectively
barcode = []
non_barcode = []

for f in filenames:
    Img = io.imread(os.path.join(Path,f), as_grey=True) 
    Img = transform.resize(Img, (66, 131))#The smallest image size was found to be 66 x 131
    Img_norm = con_str(Img)
    
    #Obtain 1D profile (horizontal line 1 x 131 at row[1/2 of all rows])
    x_n = np.zeros(Img_norm.shape[1])
    x_n = Img_norm [Img_norm.shape[0]/2, :]  

    t = np.arange(0, len(x_n))
    fr = (np.arange(-1*len(x_n)/2,len(x_n)/2,1))
                    
    # DFT 
    # Using fftshift to have the center frequency 
    x_f = np.fft.fftshift(np.fft.fft(x_n, len(x_n)))
    
    
    plt.figure
    plt.subplot(211)
    plt.plot(fr, np.abs(x_f))
    plt.xlim(40, 80)# x axis limitation to concentrate on the right side of the frequency spectrum (symmetric property of DFT)
    plt.ylim(0, 2000)# this was set to view how large each frequency component fluctuates at a universal scale
    plt.title('DFT: '+ f)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('Amplitude')
    plt.show()
    
    ##Assess frequency components above 45 Hz : 65 - (131-110) ~= 45
    #5500 set as threshold to differentiate barcode from non-barcode
    print (np.sum(np.absolute(x_f[110:len(x_f)])))
    
    if np.sum(np.absolute(x_f[110:len(x_f)])) >5500: 
        print (f) 
        barcode.append(f)
        
    else:
        non_barcode.append(f)
        

print ('Images recognized as barcodes are as follows: '+ str(barcode)) 
print ('Images recognized as non-barcodes are as follows: ' + str(non_barcode))
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 10464.6998044
# tifImage_001.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 10246.2583344
# tifImage_002.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2385.89916415
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3282.51029801
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3927.20773028
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 12559.5740108
# tifImage_006.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 8958.9272735
# tifImage_007.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 6536.50871036
# tifImage_008.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2818.37299953
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 5374.55668673
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 5038.48834462
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 4784.25719453
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3091.19027062
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 4325.15913007
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3165.32807443
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3973.00692451
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2529.30785794
# 1797.056736
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2091.07251472
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3812.45876277
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3666.15410629
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3164.80739862
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3097.51857362
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3668.71433384
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 4253.68847087
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2809.78386398
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2596.91613179
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 4128.16747478
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 1909.73830138
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2134.39097939
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 5364.40874414
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3802.16007432
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2668.66940121
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2867.22966886
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2337.26224459
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2911.81544326
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 1726.35243461
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2348.60224465
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 1336.6006879
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 1971.90150789
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 1414.62108228
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2344.09936272
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 5414.63621529
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 6661.04131826
# tifImage_044.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 12642.0064935
# tifImage_045.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 8277.93691374
# tifImage_046.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 5673.75494392
# tifImage_047.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 9634.75152258
# tifImage_048.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 12405.2012752
# tifImage_049.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 11692.5351581
# tifImage_050.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 13203.4742928
# tifImage_051.tif
# 7754.6522773
# tifImage_052.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 7341.33096664
# tifImage_053.tif
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 7561.06448639
# tifImage_054.tif
# Images recognized as barcodes are as follows: ['tifImage_001.tif', 'tifImage_002.tif', 'tifImage_006.tif', 'tifImage_007.tif', 'tifImage_008.tif', 'tifImage_044.tif', 'tifImage_045.tif', 'tifImage_046.tif', 'tifImage_047.tif', 'tifImage_048.tif', 'tifImage_049.tif', 'tifImage_050.tif', 'tifImage_051.tif', 'tifImage_052.tif', 'tifImage_053.tif', 'tifImage_054.tif']
# Images recognized as non-barcodes are as follows: ['tifImage_003.tif', 'tifImage_004.tif', 'tifImage_005.tif', 'tifImage_009.tif', 'tifImage_010.tif', 'tifImage_011.tif', 'tifImage_012.tif', 'tifImage_013.tif', 'tifImage_014.tif', 'tifImage_015.tif', 'tifImage_016.tif', 'tifImage_017.tif', 'tifImage_018.tif', 'tifImage_019.tif', 'tifImage_020.tif', 'tifImage_021.tif', 'tifImage_022.tif', 'tifImage_023.tif', 'tifImage_024.tif', 'tifImage_025.tif', 'tifImage_026.tif', 'tifImage_027.tif', 'tifImage_028.tif', 'tifImage_029.tif', 'tifImage_030.tif', 'tifImage_031.tif', 'tifImage_032.tif', 'tifImage_033.tif', 'tifImage_034.tif', 'tifImage_035.tif', 'tifImage_036.tif', 'tifImage_037.tif', 'tifImage_038.tif', 'tifImage_039.tif', 'tifImage_040.tif', 'tifImage_041.tif', 'tifImage_042.tif', 'tifImage_043.tif']

# %%
#The 1D profiles taken from barcode images contain drastic changes from white to black across the 1D frames. Hence their 
#frequency spectrums are expected to accommodate more high-frequency components. This initial guess is proved by 
#showing the magnitude of frequency spectrum of each image. In other words, the above code uses the quantity of 
#high-frequency components to differentiate barcode from non-barcode.

#An arbitrary cut-off frequency (45 Hz) and threshold value (5500) were obtained from observing the frequency spectrums. 
#Since it is given which images are barcodes, the chosen threshold value aim to ensure that all barcode images are successfully 
#categorized as "barcodes".

#Overall, the above method correctly identified 52 out of 54 images.

#It is shown that two images (007 and 008) are incorrectly categorized (non-barcodes but categorized as barcodes).
#This indicates that the used threshold value is not high enough. However, one of the barcode image (047) shows lower 
#high-frequency components relatively compared to the rest of barcode images (barely over 5500, which was the reason 5500 
#was used as the threshold value). 

#Image 007 and 008 also present drastic changes along their 1D profiles, leading to more high-frequency components in their 
#spectrums and became indiscernable from true barcode images.
