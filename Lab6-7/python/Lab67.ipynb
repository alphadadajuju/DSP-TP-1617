# %% [markdown]
# # Digital Signal Processing
#
# ### MsCV - ViBOT - MAIA

# %%
# %matplotlib inline
# %pprint off

# To make some nice plot
import matplotlib.pyplot as plt
# To play with arrays
import numpy as np
import scipy as sp
from skimage import io

from skimage import img_as_float
from matplotlib import cm
from skimage import img_as_ubyte
from scipy import signal
# Out:
# Pretty printing has been turned OFF

# %% [markdown]
# ## Filtering
# **1.1**

# %%
b, a = signal.butter(3, 0.1, 'low', analog=False)
#w, h = signal.freqs(b, a)

w, h = signal.freqz(b, a)

#plt.plot(w, 20 * np.log10(abs(h)))
plt.subplot(4, 1, 1)
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title('Butterworth lowpass filter mag response')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
plt.axvline(1, color='green') # cutoff frequency
plt.show()

b, a = signal.butter(3, 0.1, 'high', analog=False)
w, h = signal.freqz(b, a)

plt.subplot(4, 1, 2)
#plt.plot(w, 20 * np.log10(abs(h)))
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title('Butterworth highpass filter mag response')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
plt.axvline(1, color='green') # cutoff frequency
plt.show()

b, a = signal.butter(3, [0.01, 0.1], 'bandpass', analog=False)
#w, h = signal.freqs(b, a)

w, h = signal.freqz(b, a)
plt.subplot(4, 1, 3)
#plt.plot(w, 20 * np.log10(abs(h)))
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title('Butterworth bandpass filter mag response')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
plt.axvline(1, color='green') # cutoff frequency
plt.show()

b, a = signal.butter(3, [0.01, 0.1], 'bandstop', analog=False)
#w, h = signal.freqs(b, a)

w, h = signal.freqz(b, a)
plt.subplot(4, 1, 4)
#plt.plot(w, 20 * np.log10(abs(h)))
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title('Butterworth bandstop filter mag response')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
plt.axvline(1, color='green') # cutoff frequency
plt.show()

# %%
b, a = signal.cheby1(3, 1, 0.1, 'low', analog=False)
w, h = signal.freqz(b, a)

plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title('Chebyshev-I lowpass mag response (rp=1)')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
#plt.axvline(1, color='green') # cutoff frequency
#plt.axhline(-5, color='green') # rp
plt.show()

b, a = signal.cheby1(3, 1, 0.1, 'highpass', analog=False)
w, h = signal.freqz(b, a)
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title('Chebyshev-I highpass mag response (rp=1)')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
#plt.axvline(1, color='green') # cutoff frequency
#plt.axhline(-5, color='green') # rp
plt.show()

b, a = signal.cheby1(3, 1, [0.01, 0.1], 'bandpass', analog=False)
w, h = signal.freqz(b, a)
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title('Chebyshev-I bandpass mag response (rp=1)')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
#plt.axvline(1, color='green') # cutoff frequency
#plt.axhline(-5, color='green') # rp
plt.show()

b, a = signal.cheby1(3, 1, [0.01, 0.1], 'bandstop', analog=False)
w, h = signal.freqz(b, a)
plt.plot(w/np.pi, 20 * np.abs(h))
plt.xscale('log')
plt.title('Chebyshev-I bandstop mag response (rp=1)')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
#plt.axvline(1, color='green') # cutoff frequency
#plt.axhline(-5, color='green') # rp
plt.show()

# %% [markdown]
# **1.2**

# %%
b, a = signal.cheby1(3, 1, 0.3, 'low', analog=False)
w3, h3 = signal.freqz(b, a)

b, a = signal.cheby1(5, 1, 0.3, 'low', analog=False)
w5, h5 = signal.freqz(b, a)

b, a = signal.cheby1(10, 1, 0.3, 'low', analog=False)
w10, h10 = signal.freqz(b, a)

b, a = signal.cheby1(20, 1, 0.3, 'low', analog=False)
w20, h20 = signal.freqz(b, a)

plt.plot(w3/np.pi, 20 * np.abs(h3), w5/np.pi, 20 * np.abs(h5), w10/np.pi, 20 * np.abs(h10), w20/np.pi, 20 * np.abs(h20))
#plt.legend('order3', 'order5', 'order10', 'order20')
plt.xscale('log')
plt.title('Chebyshev-I lowpass mag response (rp=1)')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
#plt.grid(which='both', axis='both')
#plt.axvline(1, color='green') # cutoff frequency
#plt.axhline(-5, color='green') # rp
plt.show()

# %% [markdown]
# ## Recursive filter
#
# **2.1**

# %%
def dirac(n=0, N=40):
    # Check that the parameter are valid
    if n > N - 1:
        raise ValueError('n should be inferior to N-1')
    
    # Create the array
    s = np.zeros((N, ))
    # Place the dirac
    s[n] = 1
    
    return s


N = 40
n = 20
plt.stem(dirac(n,N))
plt.xlabel(r'$n$')
plt.ylabel(r'$\delta(k-n)$')
plt.title('Dirac function')

# %% [markdown]
# **2.2**

# %%
x = np.zeros((41))
x[20] = 1
plt.figure()
plt.stem (x)

s = 1
Ts = 1
alpha = s * Ts
a = np.exp(-alpha)


yh_plus = np.zeros((40,))
for i in range (2, N_plus):
    yh_plus[i] = x[i] + a*(alpha - 1) * x[i - 1] + 2. *a*yh_plus[i-1] - a**2*yh_plus[i -2]
    
k = np.arange (37, -1, -1)
yh_minus = np.zeros((40,))
for i in k:
    yh_minus[i] = a*(alpha+1)*x[i+1] - a**2* x[i+2] + 2. *a*yh_minus[i+1] - a**2*yh_minus[i +2]

plt.figure()
plt.stem (yh_plus)

plt.figure()
plt.stem (yh_minus)

yh = yh_minus + yh_plus
plt.figure()
plt.stem (yh)
# Out:
# <Container object of 3 artists>

# %% [markdown]
# **2.3**

# %%
x_step1 = np.zeros((40))
x_step1[10:40] = 1
plt.figure()
plt.stem (x_step1)

x_step2 = np.zeros((40))
x_step2[30:40] = 1
plt.figure()
plt.stem (x_step2)

x_step = x_step1 - x_step2
plt.figure()
plt.stem (x_step)
# Out:
# <Container object of 3 artists>

# %% [markdown]
# **2.4**

# %%
yf_plus = np.zeros((40,))
for i in range (2, 40):
    yf_plus[i] = -s*alpha*a*x_step[i-1] + 2.*a*yf_plus[i - 1] - a**2*yf_plus[i-2]
    
k = np.arange (37, -1, -1)
yf_minus = np.zeros((40,))
for i in k:
    yf_minus[i] = s*alpha*a*x_step[i+1] + 2.*a*yf_minus[i+1] - a**2*yf_minus[i+2]

plt.figure()
plt.stem (yf_plus)

plt.figure()
plt.stem (yf_minus)

yf = yf_minus + yf_plus
plt.figure()
plt.stem (yf)
# Out:
# <Container object of 3 artists>

# %% [markdown]
# **3.1**

# %%
Path = '../images/'
im = io.imread(Path.__add__('barbara.gif'))
im = img_as_float(im)

plt.figure
io.imshow(im)
plt.show()

print (im.shape[0])
# Out:
# 512

# %% [markdown]
# **3.2** , **3.3**

# %%
col = im.shape[0]
row = col

yh_plus = np.zeros((512,512))

for i in range (2, 512):
    yh_plus[i,:] = im[i,:] + a*(alpha - 1) * im[i - 1, :] + 2. *a*yh_plus[i-1, :] - a**2*yh_plus[i -2,:]
    
yh_minus = np.zeros((512,512))
k = np.arange (509, -1, -1)
for i in k:
    yh_minus[i,:] = a*(alpha+1)*im[i+1, :] - a**2* im[i+2, :] + 2. *a*yh_minus[i+1,:] - a**2*yh_minus[i +2, :]
  
Im_smooth = yh_plus + yh_minus
#plt.figure
#io.imshow(Im_smooth, cmap=plt.cm.gray)
#plt.show()


yf_plus = np.zeros((512,512))
for j in range (2, 512):
    yf_plus[:,j] = -s*alpha*a*Im_smooth[:,j-1] + 2.*a*yf_plus[:,j - 1] - a**2*yf_plus[:,j-2]
    
k = np.arange (509, -1, -1)
yf_minus = np.zeros((512,512))
for j in k:
    yf_minus[:,j] = s*alpha*a*Im_smooth[:,j+1] + 2.*a*yf_minus[:,j+1] - a**2*yf_minus[:,j+2]



Im_smooth_derv = yf_plus + yf_minus

plt.figure()
io.imshow(Im_smooth_derv, cmap=plt.cm.gray)

##
yh_plus = np.zeros((512,512))

for i in range (2, 512):
    yh_plus[:,i] = im[:,i] + a*(alpha - 1) * im[:,i - 1] + 2. *a*yh_plus[:,i-1] - a**2*yh_plus[:,i -2]
    
yh_minus = np.zeros((512,512))
k = np.arange (509, -1, -1)
for i in k:
    yh_minus[:,i] = a*(alpha+1)*im[:,i+1] - a**2* im[:,i+2] + 2. *a*yh_minus[:,i+1] - a**2*yh_minus[:,i +2]
  
Im_smooth = yh_plus + yh_minus
#plt.figure
#io.imshow(Im_smooth, cmap=plt.cm.gray)
#plt.show()


yf_plus = np.zeros((512,512))
for j in range (2, 512):
    yf_plus[j,:] = -s*alpha*a*Im_smooth[j-1,:] + 2.*a*yf_plus[j - 1,:] - a**2*yf_plus[j-2,:]
    
k = np.arange (509, -1, -1)
yf_minus = np.zeros((512,512))
for j in k:
    yf_minus[j,:] = s*alpha*a*Im_smooth[j+1,:] + 2.*a*yf_minus[j+1,:] - a**2*yf_minus[j+2,:]



Im_smooth_derv = yf_plus + yf_minus

plt.figure()
io.imshow(Im_smooth_derv, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# **3.4**
